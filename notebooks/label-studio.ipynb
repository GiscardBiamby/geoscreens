# %%
# %matplotlib inline
# %autosave 60
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
# Out:
# Autosaving every 60 seconds
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import os
from io import BytesIO
from pathlib import Path
from typing import Dict, List, Optional, Tuple, Union, cast

import cv2
import matplotlib as plt
import numpy as np
import pandas as pd
import PIL.Image as pil_img
import requests
import seaborn as sns
import sklearn as skl
from IPython.display import Image, display
from label_studio_sdk import Client, Project
from matplotlib.patches import Rectangle
from matplotlib_inline.backend_inline import set_matplotlib_formats
from tqdm.auto import tqdm

# %%
ls = Client(url="http://localhost:6008", api_key="3ac2082c83061cf1056d636a25bee65771792731")
ls.check_connection()
project_old = ls.get_project(id=5)
project_new = ls.get_project(id=18)

# %%
project_old.params
# Out:
# {'id': 5,
#  'title': 'geoscreens_005',
#  'description': '',
# ...

# %%
project_new.params
# Out:
# {'id': 18,
#  'title': 'geoscreens_006',
#  'description': '',
# ...

# %%
json.dump(project_old.params, open("./proj_old.json", "w"), sort_keys=True, indent=4)
json.dump(project_new.params, open("./proj_new.json", "w"), sort_keys=True, indent=4)

# %%
project_old.parsed_label_config
# Out:
# {'label': {'type': 'RectangleLabels',
#   'to_name': ['image'],
#   'inputs': [{'type': 'Image', 'value': 'image'}],
#   'labels': ['game_title',
#    'status_bar',
#    'play_next_round',
#    'points_bar',
#    'curr_state',
#    'view_summary',
#    'show_high_score',
#    'guess',
#    'start_game',
#    'invite_friends',
#    'play',
#    'next_round',
#    'did_you_enjoy_this_location',
#    'try_pro_for_free',
#    'other',
#    'play_again',
#    'in_game_mini_map',
#    'make_a_guess',
#    'points_bar_two_bars',
#    'try_another_map',
#    'show_full_results',
#    'high_score_box',
#    'leader_board',
#    'status_bar_white',
#    'users_bar_white',
#    'big_green_btw_rounds_box',
#    'battle_royale_wait_screen',
#    'guess_w_icon_only',
#    'guess_grey',
#    'challenge_high_score_board',
#    'game_finished_white_box',
#    'between_rounds_box_white',
#    'loading_loc_white',
#    'finished_legs_box',
#    'play_current_leg',
#    'left_menu_dark',
# ...
